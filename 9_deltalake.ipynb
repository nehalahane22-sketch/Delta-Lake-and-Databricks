# %% [markdown]
# optimize

# %%
df = spark.read.table('databricksnl.default.clonetb1')

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>income</th><th>name</th><th>tip</th></tr></thead><tbody><tr><td>1</td><td>100</td><td>aa</td><td>1</td></tr><tr><td>2</td><td>200</td><td>bb</td><td>1</td></tr><tr><td>4</td><td>400</td><td>dd </td><td>1</td></tr><tr><td>5</td><td>1000</td><td>bb</td><td>1</td></tr><tr><td>2</td><td>100</td><td>aa</td><td>1</td></tr><tr><td>6</td><td>300</td><td>cc </td><td>1</td></tr><tr><td>8</td><td>400</td><td>dd </td><td>1</td></tr><tr><td>10</td><td>100</td><td>hi bro</td><td>1</td></tr></tbody></table></div>

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/databricksnl/default/deltavol/optimization/")

# %%
# %sql
optimize delta.`/Volumes/databricksnl/default/deltavol/optimization/`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/databricksnl/default/deltavol/optimization</td><td>List(1, 2, List(1440, 1440, 1440.0, 1, 1440), List(1431, 1431, 1431.0, 2, 2862), 0, null, null, 0, 1, 2, 0, true, 0, 0, 1772340018265, 1772340020132, 8, 1, null, List(0, 0), null, 4, 4, 517, 0, null, null)</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/databricksnl/default/deltavol/optimization/`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ZORDER

# %%
# %sql
select * from delta.`/Volumes/databricksnl/default/deltavol/optimization`
WHERE cust_id = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>income</th><th>name</th><th>tip</th></tr></thead><tbody><tr><td>1</td><td>100</td><td>aa</td><td>1</td></tr><tr><td>1</td><td>100</td><td>aa</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
OPTIMIZE delta.`/Volumes/databricksnl/default/deltavol/optimization/` ZORDER BY (cust_id)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/Volumes/databricksnl/default/deltavol/optimization</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1440), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1772341078802, 1772341079192, 8, 0, null, List(0, 0), null, 4, 4, 0, 0, null, null)</td></tr></tbody></table></div>

# %% [markdown]
# liquid clustering
